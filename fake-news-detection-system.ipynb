# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
import re
import string 

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
ifind_data = pd.read_excel(r'C:\Users\91637\OneDrive\Desktop\Mini Project\fake-news-detection-system-main\fake-news-detection-system-main\Dataset.xlsx')

# %%
ifind_data.head()
# Out:
#    id                                          Statement  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# 3  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 4  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  ELECTION
#
#                   Date Label
# 0  2020-10-01 00:00:00  True
# 1  2020-10-01 00:00:00  True
# 2  2020-10-01 00:00:00  True
# 3  2020-10-01 00:00:00  True
# 4  2020-10-01 00:00:00  True

# %%
ifind_data['Label'].value_counts()
# Out:
# True    37800
# Fake    18914
# Name: Label, dtype: int64

# %%
ifind_data.rename(columns={'Statement': 'text', 'Label': 'target','Date':'date'}, inplace=True)

# %%
ifind_data['target'] = ifind_data['target'].astype(str)
ifind_data['target'].replace(['True','Fake'],[1,0], inplace=True)

# %%
ifind_data['target'].value_counts()
# Out:
# 1    37800
# 0    18914
# Name: target, dtype: int64

# %%
ifind_data.head()
# Out:
#    id                                               text  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# 3  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 4  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  ELECTION
#
#                   date  target
# 0  2020-10-01 00:00:00       1
# 1  2020-10-01 00:00:00       1
# 2  2020-10-01 00:00:00       1
# 3  2020-10-01 00:00:00       1
# 4  2020-10-01 00:00:00       1

# %%
print(ifind_data["target"].value_counts())
g1 = plt.pie(ifind_data["target"].value_counts().values,explode=[0,0],labels=ifind_data.target.value_counts().index, autopct='%1.1f%%',colors=['SkyBlue','PeachPuff'])
plt.show()
# Out:
# 1    37800
# 0    18914
# Name: target, dtype: int64

# %%
print(ifind_data.Category.value_counts())
plt.figure(figsize=(10, 5))

ax = sns.countplot(x="Category",  hue='target', data=ifind_data, palette="pastel")
plt.title("Distribution of The Subject According to Real and Fake Data")
# Out:
# GOVERNMENT    10923
# VIOLENCE      10578
# COVID-19       8710
# POLITICS       8670
# ELECTION       8396
# TERROR         4384
# MISLEADING     4059
# TRAD            976
# MISLEADIND       18
# Name: Category, dtype: int64
# Text(0.5, 1.0, 'Distribution of The Subject According to Real and Fake Data')

# %%
print(ifind_data.Web.value_counts())
plt.figure(figsize=(30, 10))

ax = sns.countplot(x="Web",  hue='target', data=ifind_data, palette="pastel")
plt.title("Distribution of The Subject According to Real and Fake Data")
# Out:
# TRIBUNEINDIA        11832
# AUGMENT             11321
# THEPRINT             8582
# THESTATESMAN         7202
# THESTATEMAN          4048
# INDIANEXPRESS        3983
# NEWSMOBILE           2422
# INDIATODAY           1698
# BOOMLIVE              806
# CNN                   778
# NEWSMETER             572
# ONEINDIA              549
# BSMEDIA               449
# TEEKHIMIRCHI          387
# FACTCRESCENDO         272
# AFP                   267
# TIMESNOW              238
# THELOGICALINDIAN      221
# DIGITEYE              175
# FACTLY                174
# THELOGICALINDIA       173
# FACTCHECKER           163
# DAPAAN                136
# DNAINDIA              121
# ALT                    59
# WAHSARKAR              42
# ENGLISHTRIBUNE         21
# INDUSTANTIMES          15
# NDTV                    8
# Name: Web, dtype: int64
# Text(0.5, 1.0, 'Distribution of The Subject According to Real and Fake Data')

# %%
ifind_data.groupby(['Web','target'])['id'].count()
# Out:
# Web               target
# AFP               0           267
# ALT               0            59
# AUGMENT           0         11321
# BOOMLIVE          0           806
# BSMEDIA           1           449
# CNN               1           778
# DAPAAN            1           136
# DIGITEYE          0           175
# DNAINDIA          1           121
# ENGLISHTRIBUNE    1            21
# FACTCHECKER       0           163
# FACTCRESCENDO     0           272
# FACTLY            1           174
# INDIANEXPRESS     1          3983
# INDIATODAY        0          1606
#                   1            92
# INDUSTANTIMES     1            15
# NDTV              1             8
# NEWSMETER         0           506
#                   1            66
# NEWSMOBILE        0          2190
#                   1           232
# ONEINDIA          0           549
# TEEKHIMIRCHI      0           262
#                   1           125
# THELOGICALINDIA   0           173
# THELOGICALINDIAN  0           221
# THEPRINT          0           344
#                   1          8238
# THESTATEMAN       1          4048
# THESTATESMAN      1          7202
# TIMESNOW          1           238
# TRIBUNEINDIA      1         11832
# WAHSARKAR         1            42
# Name: id, dtype: int64

# %%
data = ifind_data[['text','target']].copy()

# %%
data.head()
# Out:
#                                                 text  target
# 0  WHO praises India's Aarogya Setu app, says it ...       1
# 1  In Delhi, Deputy US Secretary of State Stephen...       1
# 2  LAC tensions: China's strategy behind delibera...       1
# 3  India has signed 250 documents on Space cooper...       1
# 4  Tamil Nadu chief minister's mother passes away...       1

# %%
first_text = data.text[10]
first_text
# Out:
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor'"

# %%
#Removal of html content
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(first_text, "html.parser")
first_text = soup.get_text()
first_text
# Out:
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor'"

# %%
#removal of punctuation marks and special characters
first_text = re.sub('\[[^]]*\]', ' ', first_text)
first_text = re.sub('[^a-zA-Z]',' ',first_text)  # replaces non-alphabets with spaces
first_text = first_text.lower() # Converting from uppercase to lowercase
first_text
# Out:
# 'amid stubble burning  delhi s air quality deteriorates to  very poor '

# %%
 nltk.download('punkt')
 nltk.download("stopwords") 
 nltk.download('wordnet')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91637\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91637\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91637\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
#tokenization and stopwords
first_text = nltk.word_tokenize(first_text)
first_text = [ word for word in first_text if not word in set(stopwords.words("english"))]
first_text
# Out:
# ['amid',
#  'stubble',
#  'burning',
#  'delhi',
#  'air',
#  'quality',
#  'deteriorates',
#  'poor']

# %%
#lemmatization
import nltk
nltk.download('omw-1.4')
first_text = "Amid stubble burning, Delhi's air quality deteriorates to 'very poor "
lemma = nltk.WordNetLemmatizer()
first_text = [ lemma.lemmatize(word) for word in first_text.split()] 
first_text = " ".join(first_text)
first_text
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\91637\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor"

# %%
#Removal of HTML Contents
def remove_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removal of Punctuation Marks
def remove_punctuations(text):
    return re.sub('\[[^]]*\]', '', text)

# Removal of Special Characters
def remove_characters(text):
    return re.sub("[^a-zA-Z]"," ",text)

# %%
#Removal of stopwords 
def remove_stopwords_and_lemmatization(text):
    final_text = []
    text = text.lower()
    text = nltk.word_tokenize(text)
    #lemma = nltk.WordNetLemmatizer()
    
    final_text = [word for word in text if word not in stopwords.words('english')]
    return " ".join(final_text)

# %%
def remove_stopwords(text):
    final_text = []
    final_text = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    return " ".join(final_text)

# %%
#Total function
def cleaning(text):
    text = remove_html(text)
    text = remove_punctuations(text)
    text = remove_characters(text)
    text = remove_stopwords_and_lemmatization(text)
    return text

# %%
data['text']=data['text'].apply(remove_html)
data['text']=data['text'].apply(remove_punctuations)
data['text']=data['text'].apply(remove_characters)
data['text']=data['text'].apply(remove_stopwords)

# %%
data.head()
# Out:
#                                                 text  target
# 0  praises India Aarogya Setu app says helped ide...       1
# 1  Delhi Deputy US Secretary State Stephen Biegun...       1
# 2  LAC tensions China strategy behind deliberatel...       1
# 3  India signed documents Space cooperation count...       1
# 4       Tamil Nadu chief minister mother passes away       1

# %%
data.tail()
# Out:
#                                                     text  target
# 56709    Fact Check Bruce Lee playing ping pong Nunchaku       0
# 56710            Fact Check Japan construct bridge hours       0
# 56711  Fact Check Viral video Mexico earthquake years...       0
# 56712  Fact Check Ballet performance Chinese couple g...       0
# 56713  Fact Check little boy crossing Jordan alone lo...       0

# %%
pip install wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: wordcloud in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg (from matplotlib->wordcloud) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from wordcloud import WordCloud,STOPWORDS
plt.figure(figsize = (15,15))
wc = WordCloud(max_words = 500 , width = 1000 , height = 500 , stopwords = STOPWORDS).generate(" ".join(data[data.target == 1].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
plt.figure(figsize = (15,15))
wc = WordCloud(max_words = 500 , width = 1000 , height = 500 , stopwords = STOPWORDS).generate(" ".join(data[data.target == 0].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,8))
text_len=data[data['target']==0]['text'].str.split().map(lambda x: len(x))
ax1.hist(text_len,color='SkyBlue')
ax1.set_title('Fake news text')
text_len=data[data['target']==1]['text'].str.split().map(lambda x: len(x))
ax2.hist(text_len,color='PeachPuff')
ax2.set_title('Real news text')
fig.suptitle('Words in texts')
plt.show()

# %%
texts = ' '.join(data['text'])

# %%
string = texts.split(" ")

# %%
def draw_n_gram(string,i):
    n_gram = (pd.Series(nltk.ngrams(string, i)).value_counts())[:15]
    n_gram_df=pd.DataFrame(n_gram)
    n_gram_df = n_gram_df.reset_index()
    n_gram_df = n_gram_df.rename(columns={"index": "word", 0: "count"})
    print(n_gram_df.head())
    plt.figure(figsize = (16,9))
    return sns.barplot(x='count',y='word', data=n_gram_df)

# %%
draw_n_gram(string,1)
# Out:
#        word  count
# 0   (Fact,)   9958
# 1  (Check,)   9045
# 2  (India,)   5122
# 3    (BJP,)   4680
# 4   (Modi,)   4518
# <AxesSubplot: xlabel='count', ylabel='word'>

# %%
draw_n_gram(string,2)
# Out:
#               word  count
# 0    (Fact, Check)   9011
# 1       (PM, Modi)   2328
# 2  (Rahul, Gandhi)   1228
# 3     (Amit, Shah)    739
# 4           (J, K)    711
# <AxesSubplot: xlabel='count', ylabel='word'>

# %%
draw_n_gram(string,3)
# Out:
#                        word  count
# 0        (Fact, Check, Old)    638
# 1      (Fact, Check, Viral)    429
# 2      (Fact, Check, Video)    373
# 3  (Sushant, Singh, Rajput)    189
# 4      (Fact, Check, video)    176
# <AxesSubplot: xlabel='count', ylabel='word'>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X = data['text']
y = data['target']
td = TfidfVectorizer(max_features = 4500)
X = td.fit_transform(X).toarray()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
print('\n the total number of training data :',y_train.shape)
# Out:
#  the total number of training data : (39699,)

# %%
print('\n the total number of testing data :',y_test.shape)
# Out:
#  the total number of testing data : (17015,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
#from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier

# %%
#classifier_lr = LogisticRegression()
#classifier_lr.fit(X_train, y_train)
#y_pred = classifier_lr.predict(X_test)
# Classification metrics
#classification_report = classification_report(y_test, y_pred)
#print('\n Accuracy: ', accuracy_score(y_test, y_pred))

# %%
# Training the classifier & predicting on test data
classifier_nb = MultinomialNB()
classifier_nb.fit(X_train, y_train)
y_pred = classifier_nb.predict(X_test)
# Classification metrics

print('\n Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
#  Accuracy:  0.9286511901263591

# %%
#classifier_rf = RandomForestClassifier(n_estimators=10)
#classifier_rf.fit(X_train, y_train)
#y_pred = classifier_rf.predict(X_test)
#print('\n Accuracy: ', accuracy_score(y_test, y_pred))

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\91637\appdata\roaming\python\python311\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (8.1.3)
# Requirement already satisfied: joblib in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91637\appdata\roaming\python\python311\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg (from nltk>=3.8->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from textblob import TextBlob
from datetime import datetime

# %%
def timesofindia():
    url = "https://timesofindia.indiatimes.com/home/headlines"
    page_request = requests.get(url)
    data = page_request.content
    soup = BeautifulSoup(data,"html.parser")
    times_of_india_news = []
    counter = 0
    for divtag in soup.find_all('div', {'class': 'headlines-list'}):
        for ultag in divtag.find_all('ul', {'class': 'clearfix'}):
            if (counter <= 10):
                for litag in ultag.find_all('li'):
                    counter = counter + 1
                    print(str(counter),datetime.today().strftime('%Y-%m-%d') + "." + litag.text + " - https://timesofindia.indiatimes.com" + litag.find('a')['href'])
                    times_of_india_news.append(['Times of India',datetime.today().strftime('%Y-%m-%d'),litag.text])
    return times_of_india_news

# %%
times_of_india_news = timesofindia()
# Out:
# 1 2024-05-14.Helping Hamas & Trump: Why Biden just made his biggest blunder12 May 2024, 2015 hrs IST - https://timesofindia.indiatimes.com/world/5-reasons-why-biden-just-made-his-biggest-blunder-yet/articleshow/110055637.cms
# 2 2024-05-14.Apple and Google have announced a Bluetooth devices partnership - https://timesofindia.indiatimes.com/technology/tech-news/apple-and-google-have-announced-a-bluetooth-devices-partnership-what-it-means-for-users/articleshow/110094625.cms
# 3 2024-05-14.Heavy rain wreaks havoc in Bengaluru, over 1,000 trees fall in 7 days - https://timesofindia.indiatimes.com/city/bengaluru/1000-trees-gone-in-7-days-in-bengaluru-bbmp-plans-spot-auction/articleshow/110099173.cms
# 4 2024-05-14.Blinken makes unannounced visit to Ukraine to show US support - https://timesofindia.indiatimes.com/world/us/blinken-makes-unannounced-visit-to-ukraine-to-show-us-support-for-kyiv-as-russian-attacks-intensify/articleshow/110100198.cms
# 5 2024-05-14.11-month low: Retail inflation dips to 4.8% in April - https://timesofindia.indiatimes.com/business/india-business/4-8-retail-inflation-hits-11-month-low/articleshow/110094350.cms
# 6 2024-05-14.Ola CEO to Microsoft's LinkedIn: ... Luckily my team takes screenshots - https://timesofindia.indiatimes.com/technology/social/ola-ceo-bhavish-aggarwal-to-dear-linkedin-luckily-my-team-takes-screenshots/articleshow/110019774.cms
# 7 2024-05-14.Hyderabad Lok Sabha seat: It's Owaisi's legacy vs Madhavi's dare - https://timesofindia.indiatimes.com/city/hyderabad/hyderabad-lok-sabha-seat-its-owaisis-legacy-vs-madhavis-dare/articleshow/110099837.cms
# 8 2024-05-14.Mumbai billboard collapse: Toll rises to 14, over 70 injured - https://timesofindia.indiatimes.com/city/mumbai/mumbai-rains-dust-storm-thunderstorm-gusty-winds-hits-maharashtra-billboard-collapse-flight-train-delay/liveblog/110090456.cms
# 9 2024-05-14.UP police constable gets himself shot to trick lover’s family, arrested - https://timesofindia.indiatimes.com/city/meerut/constable-gets-himself-shot-to-trick-lovers-family-arrested/articleshow/110098418.cms
# 10 2024-05-14.Hrithik Roshan slams this Apple ad, calls it 'sad & ignorant' - https://timesofindia.indiatimes.com/technology/tech-news/hrithik-roshan-calls-this-apple-ad-sad-and-ignorant/articleshow/110030053.cms
# 11 2024-05-14.How Virat Kohli has symbolised RCB's resurgence - https://timesofindia.indiatimes.com/sports/cricket/ipl/top-stories/ipl-2024-how-virat-kohli-has-symbolised-rcbs-resurgence/articleshow/110100120.cms
# 12 2024-05-14.IPL playoff scenarios: Which team will join KKR in top two? - https://timesofindia.indiatimes.com/sports/cricket/ipl/top-stories/ipl-playoff-scenarios-which-team-will-join-kolkata-knight-riders-in-top-two/articleshow/110098805.cms

# %%
pip install -U pip
# Out:
# Requirement already satisfied: pip in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (24.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (69.5.1)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install feedparser
# Out:
# Requirement already satisfied: feedparser in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (6.0.8)
# Requirement already satisfied: sgmllib3k in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from feedparser) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install "beautifulsoup4==4.9.1"
# Out:
# Requirement already satisfied: beautifulsoup4==4.9.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4==4.9.1) (2.5)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install "dateparser==0.7.6"
# Out:
# Requirement already satisfied: dateparser==0.7.6 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (0.7.6)
# Requirement already satisfied: python-dateutil in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg (from dateparser==0.7.6) (2.8.1)
# Requirement already satisfied: pytz in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from dateparser==0.7.6) (2022.7)
# Requirement already satisfied: regex!=2019.02.19 in c:\users\91637\appdata\roaming\python\python311\site-packages (from dateparser==0.7.6) (2023.12.25)
# Requirement already satisfied: tzlocal in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from dateparser==0.7.6) (5.2)
# Requirement already satisfied: six>=1.5 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg (from python-dateutil->dateparser==0.7.6) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from tzlocal->dateparser==0.7.6) (2022.7)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install "requests==2.24.0"
# Out:
# Requirement already satisfied: requests==2.24.0 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (2.24.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from requests==2.24.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from requests==2.24.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from requests==2.24.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from requests==2.24.0) (2022.9.24)
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install "feedparser==6.0.8"
# Out:
# Requirement already satisfied: feedparser==6.0.8 in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (6.0.8)
# Requirement already satisfied: sgmllib3k in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (from feedparser==6.0.8) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
pip install --no-deps pygooglenews
# Out:
# Requirement already satisfied: pygooglenews in c:\users\91637\appdata\local\programs\python\python311\lib\site-packages (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\eth_brownie-1.19.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py-1.11.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pycryptodome-3.15.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments-2.13.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pygments_lexer_solidity-0.7.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyjwt-1.7.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyparsing-3.0.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyrsistent-0.18.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest-6.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_forked-1.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pytest_xdist-1.34.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dateutil-2.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\python_dotenv-0.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pythx-1.6.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_ast-1.2.9-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\py_solc_x-1.1.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\rlp-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\semantic_version-2.10.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\six-1.16.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\sortedcontainers-2.4.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toml-0.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tomli-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\toolz-0.12.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\tqdm-4.64.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\varint-1.0.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vvm-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\vyper-0.3.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wcwidth-0.2.5-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\web3-5.31.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\websockets-9.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wheel-0.37.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\wrapt-1.14.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\91637\appdata\local\programs\python\python311\lib\site-packages\yarl-1.8.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from pygooglenews import GoogleNews
import json
import time



def fetching_google_news():
    gn = GoogleNews()
    top = gn.top_news()

    entries = top["entries"]
    count = 0
    google_news = []
    for entry in entries:
        count = count + 1
        print( str(count) + ". " + entry["title"] + entry["published"])
        google_news.append(['Google News',entry["published"],entry["title"] ])
        time.sleep(1)
    return google_news

# %%
google_news = fetching_google_news()
# Out:
# 1. Michael Cohen implicates Donald Trump in testimony at hush money trial - The Associated PressTue, 14 May 2024 01:58:00 GMT
# 2. Gaza war: Palestinians flee as Israeli forces go back into Jabalia - BBC.comMon, 13 May 2024 23:51:11 GMT
# 3. Trump's surrogates help him skirt his gag order - The Washington PostMon, 13 May 2024 23:58:00 GMT
# 4. Cargo ship will ‘hopefully’ be refloated this week after explosives remove some Baltimore bridge wreckage from vessel - CNNMon, 13 May 2024 23:58:00 GMT
# 5. What is Georgia’s ‘foreign agents’ bill, and why is Europe so alarmed? - CNNMon, 13 May 2024 18:38:00 GMT
# 6. Sergei Shoigu's sacking points to yet more attrition in Ukraine - The EconomistMon, 13 May 2024 11:09:44 GMT
# 7. Canada wildfires hit northern U.S. air quality - AxiosTue, 14 May 2024 02:58:25 GMT
# 8. 3 men charged in Whitey Bulger's 2018 prison killing have plea deals, prosecutors say - The Associated PressTue, 14 May 2024 00:16:00 GMT
# 9. Jerry Seinfeld's Teen Girlfriend Saga Resurfaces After Duke Walkout - The Daily BeastMon, 13 May 2024 23:00:41 GMT
# 10. Video shows panic in church packed with kids after teen armed with rifle tries to storm service - New York PostMon, 13 May 2024 19:24:00 GMT
# 11. Russia-Ukraine war: Russian troops locked in battles with Ukrainian soldiers around Vovchansk - The Associated PressMon, 13 May 2024 21:48:00 GMT
# 12. Britain faces its 'most dangerous' years in history, PM Rishi Sunak warns in preelection bid - CNBCMon, 13 May 2024 08:45:58 GMT
# 13. Legendary treasure that apparently belonged to notorious 18th-century conman unearthed in Poland - CBS NewsMon, 13 May 2024 18:15:33 GMT
# 14. Four dead, several feared trapped as billboard falls over during Mumbai rainstorm - CNNMon, 13 May 2024 19:48:00 GMT
# 15. New Rules to Overhaul Electric Grids Could Boost Wind and Solar Power - The New York TimesMon, 13 May 2024 22:22:17 GMT
# 16. The Controversy Around Bumble's Anti-Celibacy Billboards - The CutMon, 13 May 2024 21:42:00 GMT
# 17. Airlines are trying to stop Biden from enforcing 'junk fees' rule - The Washington PostTue, 14 May 2024 02:03:00 GMT
# 18. GameStop, AMC shares skyrocket after meme stock trader posts for first time in 3 years - CNNTue, 14 May 2024 02:18:00 GMT
# 19. OpenAI's new voice assistant ChatGPT-4o smokes Apple's Siri - Business InsiderMon, 13 May 2024 21:12:00 GMT
# 20. First M2 iPad Air reviews call it 'the iPad to get' - 9to5MacMon, 13 May 2024 22:22:00 GMT
# 21. Apple Stock: iPhone Maker Close To Deal With OpenAI - Investor's Business DailyMon, 13 May 2024 20:48:00 GMT
# 22. The Pixel 8a has a 'Snapshot' widget and 'Inside Out' wallpapers - 9to5GoogleMon, 13 May 2024 14:30:00 GMT
# 23. Bradley Cooper and Gigi Hadid Kiss During Taylor Swift's Eras Tour Show in Paris - Entertainment TonightMon, 13 May 2024 21:46:00 GMT
# 24. Kelly Clarkson Sets Record Straight on Ozempic Rumors Amid Weight Loss - E! NEWSTue, 14 May 2024 03:52:52 GMT
# 25. Khloé Kardashian brings kids to see dad Tristan Thompson play professionally for first time - Page SixTue, 14 May 2024 02:04:00 GMT
# 26. Kendrick Lamar’s Drake diss track debuts at number one in the US - The GuardianMon, 13 May 2024 20:32:00 GMT
# 27. Celtics take control of series with Game 4 win vs. Cavaliers - ESPNTue, 14 May 2024 01:54:00 GMT
# 28. Ripple Effects of Jared Goff Contract on Dak Prescott, More NFL QB Extension Talks - Bleacher ReportMon, 13 May 2024 23:26:15 GMT
# 29. Keeler: Avalanche gave Valeri Nichushkin a second chance. He blew it. It’s time to move on. - The Denver PostTue, 14 May 2024 02:27:54 GMT
# 30. Exclusive: Cowboys will face Browns in Week 1 to mark Tom Brady's FOX Sports debut - FOX SportsMon, 13 May 2024 21:27:18 GMT
# 31. Launch Roundup: Starliner prepares for second launch attempt; Falcon 9 to launch first batch into new spy constellation - NASASpaceFlight.com - NASASpaceflight.comMon, 13 May 2024 23:01:02 GMT
# 32. Not Just Auroras: Here's the Tech That Got Hit by This Weekend's Solar Storm - GizmodoMon, 13 May 2024 19:15:00 GMT
# 33. SpaceX Starship's next launch 'probably 3 to 5 weeks' away, Elon Musk says - Space.comMon, 13 May 2024 22:00:06 GMT
# 34. SpaceX launches 23 Starlink satellites from Cape Canaveral Space Force Station - VideoFromSpaceMon, 13 May 2024 12:22:24 GMT
# 35. Raw milk fans plan to drink up as experts warn of high levels of H5N1 virus - Ars TechnicaMon, 13 May 2024 22:58:27 GMT
# 36. The First Person to Receive a Pig Kidney Transplant Has Died - WIREDMon, 13 May 2024 19:05:09 GMT
# 37. What the results of Wegovy’s longest clinical trial yet show about weight loss, side effects and heart protection - CNNMon, 13 May 2024 22:37:00 GMT
# 38. KP.2 is now the dominant COVID variant. Experts say US may see a summer increase in cases - ABC NewsMon, 13 May 2024 21:09:35 GMT

# %%
news_content = []

# %%
news_content+=times_of_india_news
news_content+= google_news
news_content_df = pd.DataFrame(news_content,columns = ['New_Site','Date' , 'Title'])

# %%
news_content_df.head()
# Out:
#          New_Site        Date  \
# 0  Times of India  2024-05-14
# 1  Times of India  2024-05-14
# 2  Times of India  2024-05-14
# 3  Times of India  2024-05-14
# 4  Times of India  2024-05-14
#
#                                                Title
# 0  Helping Hamas & Trump: Why Biden just made his...
# 1  Apple and Google have announced a Bluetooth de...
# 2  Heavy rain wreaks havoc in Bengaluru, over 1,0...
# 3  Blinken makes unannounced visit to Ukraine to ...
# 4  11-month low: Retail inflation dips to 4.8% in...

# %%
textblob_sentiment=[]
for index , row in news_content_df.iterrows():
    title = row['Title']
    txt= TextBlob(title)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([a,b])

# %%
news_content_df['Text_blob_Polarity'] , news_content_df['Text_blob_Subjectivity'] = zip(*textblob_sentiment)

# %%
news_content_df['Title_clean']=news_content_df['Title'].apply(remove_html)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_punctuations)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_characters)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_stopwords)

# %%
X_real = td.transform(news_content_df['Title_clean']).toarray()

# %%
news_content_df['Prediction_LR'] = classifier_lr.predict(X_real)
news_content_df['Prediction_RF'] = classifier_rf.predict(X_real)
news_content_df['Prediction_NB'] = classifier_nb.predict(X_real)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 news_content_df['Prediction_LR'] = classifier_lr.predict(X_real)
#       2 news_content_df['Prediction_RF'] = classifier_rf.predict(X_real)
#       3 news_content_df['Prediction_NB'] = classifier_nb.predict(X_real)
#
# NameError: name 'classifier_lr' is not defined

# %%
news_content_df['Prediction_LR'].replace([1,0], ['True','Fake'],inplace=True)
news_content_df['Prediction_RF'].replace([1,0], ['True','Fake'],inplace=True)
news_content_df['Prediction_NB'].replace([1,0], ['True','Fake'],inplace=True)

# %%
news_content_df.head()
# Out:
#          New_Site        Date  \
# 0  Times of India  2024-03-22
# 1  Times of India  2024-03-22
# 2  Times of India  2024-03-22
# 3  Times of India  2024-03-22
# 4  Times of India  2024-03-22
#
#                                                Title  Text_blob_Polarity  \
# 0  Water crisis: People of Bengaluru need to take...                 0.0
# 1  HC notice to Google India after techie loses a...                -0.3
# 2  Isro completes 2nd key landing experiment of r...                 0.0
# 3  Kejriwal 2nd sitting CM to be arrested after J...                 0.0
# 4  Why this Formula One team chief feels Microsof...                -0.5
#
#    Text_blob_Subjectivity                                        Title_clean  \
# 0                     0.0  Water crisis People Bengaluru need take charge...
# 1                     0.1  HC notice Google India techie loses access Goo...
# 2                     0.5  Isro completes nd key landing experiment reusa...
# 3                     0.0       Kejriwal nd sitting CM arrested Jayalalithaa
# 4                     0.2  Formula One team chief feels Microsoft Excel u...
#
#   Prediction_LR Prediction_RF Prediction_NB
# 0          True          True          True
# 1          True          True          True
# 2          True          True          True
# 3          True          True          True
# 4          True          True          True

# %%
news_content_df.to_excel('Result.xlsx')

# %%
def real_time_prediction(news):
  news_transformed = td.transform([news]).toarray()
 # Prediction_LR = classifier_lr.predict(news_transformed)
  #Prediction_RF = classifier_rf.predict(news_transformed)
  Prediction_NB = classifier_nb.predict(news_transformed)
  #Prediction_LR = ['Real'  if i == 1 else 'Fake' for i in Prediction_LR ]
  #print(f"Based on Logistic Regression model this News is ::{Prediction_LR[0]}")
  #Prediction_RF = ['Real'  if i == 1 else 'Fake' for i in Prediction_RF ]
  #print(f"Based on  Random Forest Model this News is ::{Prediction_RF[0]}")
  Prediction_NB = ['Real'  if i == 1 else 'Fake' for i in Prediction_NB ]
  print(f"Based on Naive Bayes model this News is :: {Prediction_NB[0]} ")

# %%
news = input("Please Enter the News which you want to predict : ")
real_time_prediction(news)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 news = input("Please Enter the News which you want to predict : ")
# ----> 2 real_time_prediction(news)
#
# NameError: name 'real_time_prediction' is not defined
